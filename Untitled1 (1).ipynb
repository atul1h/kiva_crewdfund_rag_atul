# %%
import pandas as pd
# df=pd.read_csv(r"C:\Users\Atul\Desktop\kiva_loans.csv",low_memory=False)
# df.head
df =pd.read_csv(r"/impactguru/kickstarter.csv")

# %%
df.head()
# Out:
#    Unnamed: 0          id  backers_count  \
# 0           0   857125548              1
# 1           1  1038659700              2
# 2           2  1238331911              0
# 3           3   189217262              0
# 4           4  1260075071              1
#
#                                                blurb currency     goal  \
# 0  Exploring paint and its place in a digital world.      USD   2000.0
# 1  Mike Fassio wants a side-by-side photo of me a...      USD     10.0
# 2  I need your help to get a nice graphics tablet...      USD    900.0
# 3  I want to create a Nature Photograph Series of...      USD    900.0
# 4  I want to bring colour to the world in my own ...      GBP  15000.0
#
#            launched_at             deadline location.country  \
# 0  2015-03-19 22:34:57  2015-04-30 23:12:00               US
# 1  2014-07-17 01:55:07  2014-07-27 01:55:07               US
# 2  2014-07-30 16:29:13  2014-08-29 16:29:13               US
# 3  2015-05-11 16:09:11  2015-05-31 16:09:11               US
# 4  2015-02-06 21:52:02  2015-03-08 20:52:02               GB
#
#                                                 name  ...  days_to_deadline  \
# 0                                              Remix  ...              42.0
# 1  Photo of Grant and Hazel eating cake with bare...  ...              10.0
# 2                   Minecraft Digital Art/Animations  ...              30.0
# 3                Sacramento Nature Photograph Series  ...              20.0
# 4                North Africa art project - my dream  ...              30.0
#
#      goal_USD category_name category_slug  blurb_length location_type  \
# 0   2000.0000   Digital Art           art           9.0          Town
# 1     10.0000   Digital Art           art          21.0          Town
# 2    900.0000   Digital Art           art          12.0          Town
# 3    900.0000   Digital Art           art          17.0          Town
# 4  22801.6545   Digital Art           art          26.0        County
#
#    location_country  location_state  location_displayable_name  binary_state
# 0                US              NY               New York, NY        failed
# 1                US              WA                Seattle, WA        failed
# 2                US              VA                 Moneta, VA        failed
# 3                US              CA             Sacramento, CA        failed
# 4                GB         England                  Essex, UK        failed
#
# [5 rows x 30 columns]

# %%
df = df.sample(n=10000, random_state=42)
df = df.drop_duplicates()
df = df.dropna(subset=["goal", "usd_pledged", "name", "category_name"])

df["name"] = df["name"].str.lower()
df["category"] = df["category_name"].str.lower()

df["funding_ratio"] = df["usd_pledged"] / df["goal"]
df.head()
# Out:
#        Unnamed: 0          id  backers_count  \
# 7503         3407  1352357347              0
# 22628        2148  1716150990             89
# 15443        3155  1337211708             11
# 9350         1158  1827598775             87
# 5979         1883   827596587            185
#
#                                                    blurb currency     goal  \
# 7503   Hi everybody, this is Explorate Designs. We ar...      AUD    200.0
# 22628  Turn three whimsical paintings into beautiful ...      USD   1500.0
# 15443  I need to finish a body of work for an art sho...      USD    300.0
# 9350   An interactive, community garden made of metal...      USD   5500.0
# 5979   Exploring the meeting ground between paint, fi...      USD  35000.0
#
#                launched_at             deadline location.country  \
# 7503   2015-04-25 19:20:24  2015-05-02 02:00:00               AU
# 22628  2013-04-01 23:58:17  2013-05-08 03:59:00               US
# 15443  2011-05-28 02:24:13  2011-06-20 02:00:00               US
# 9350   2011-08-02 05:13:20  2011-08-23 01:00:00               US
# 5979   2012-07-19 05:48:49  2012-08-18 05:48:49               NZ
#
#                                                     name  ...  category_name  \
# 7503                                 paint up | spray on  ...     Public Art
# 22628       raccoons, a fox &  an octopus in the bathtub  ...       Painting
# 15443      "abstraction of soul" series needs completion  ...       Painting
# 9350   the mathematician's garden: an interactive scu...  ...      Sculpture
# 5979   destinies lost + found: vincent ward shanghai ...  ...    Mixed Media
#
#       category_slug blurb_length location_type  location_country  \
# 7503            art         22.0        Suburb                AU
# 22628           art          8.0          Town                US
# 15443           art         29.0          Town                US
# 9350            art         18.0          Town                US
# 5979            art         19.0        Suburb                NZ
#
#         location_state  location_displayable_name  binary_state     category  \
# 7503               QLD               West End, AU        failed   public art
# 22628               NC                Raleigh, NC    successful     painting
# 15443               LA            New Orleans, LA    successful     painting
# 9350                CA                Oakland, CA    successful    sculpture
# 5979   Auckland Region        Western Springs, NZ        failed  mixed media
#
#        funding_ratio
# 7503        0.000000
# 22628       1.493107
# 15443       1.116667
# 9350        1.023636
# 5979        0.789435
#
# [5 rows x 32 columns]

# %%
# Install sentence-transformers and LangChain Groq
# !pip install -q sentence-transformers langchain langchain-groq
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 6.0 MB/s eta 0:00:00

# %%
import torch
from sentence_transformers import SentenceTransformer
from sentence_transformers.util import cos_sim
from langchain_groq import ChatGroq

# %%
docs = []

for category, group in df.groupby("category_name"):
    avg_goal = group["goal"].mean()
    success_rate = (group["state"] == "successful").mean()
    avg_funding_ratio = group["funding_ratio"].mean()
    project_count = len(group)

    doc = (
        f"Category: {category}. "
        f"Number of projects: {project_count}. "
        f"Average goal amount: {avg_goal:.2f}. "
        f"Success rate: {success_rate:.2%}. "
        f"Average funding ratio: {avg_funding_ratio:.2f}, "
        f"indicating how much projects exceed their goals on average."
    )

    docs.append(doc)
print(len(docs))
print(docs[:2])
# Out:
# 43
# ['Category: Accessories. Number of projects: 428. Average goal amount: 17921.66. Success rate: 26.64%. Average funding ratio: 1.14, indicating how much projects exceed their goals on average.', 'Category: Anthologies. Number of projects: 52. Average goal amount: 12406.60. Success rate: 71.15%. Average funding ratio: 1.56, indicating how much projects exceed their goals on average.']

# %%
import os

# %%
groq = "gsk_GR4wnxJuLoKsK0u1..............FDvSQHYTqYpSo5z"  # Replace with your Groq API key
os.environ['GROQ_API_KEY'] = groq

# %%
# --------------------------------------------------
# 5. EMBEDDINGS (OPEN SOURCE)
# --------------------------------------------------
embedder = SentenceTransformer("all-MiniLM-L6-v2")
doc_embeddings = embedder.encode(docs, convert_to_tensor=True)

# --------------------------------------------------
# 6. RETRIEVER (IN-MEMORY)
# --------------------------------------------------
def retrieve_docs(query, top_n=3):
    query_embedding = embedder.encode(query, convert_to_tensor=True)
    scores = cos_sim(query_embedding, doc_embeddings)[0]
    top_results = torch.topk(scores, k=top_n)
    return [docs[idx] for idx in top_results.indices]
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
llm = ChatGroq(
    model="openai/gpt-oss-safeguard-20b",
    temperature=0.2
)

# %%
# --------------------------------------------------
# 8. RAG INSIGHT FUNCTION
# --------------------------------------------------
def get_insight_from_rag(query: str) -> str:
    retrieved_docs = retrieve_docs(query)
    context = "\n".join(retrieved_docs)

    prompt = f"""
You are an analyst answering questions using crowdfunding data.

Context:
{context}

Question:
{query}

Answer clearly and concisely.
"""

    response = llm.invoke(prompt)
    return response.content

# --------------------------------------------------
# 9. EXAMPLE RUN
# --------------------------------------------------
if __name__ == "__main__":
    query = "Which crowdfunding categories perform the best?"
    answer = get_insight_from_rag(query)
    print("\nANSWER:\n")
    print(answer)
# Out:
# ANSWER:
#
# **Best‑performing category:** **Conceptual Art**
# - Highest success rate (39.46 %)
# - Strong funding ratio (0.68)
# - Reasonable number of projects (294)
#
# Mixed Media has the most projects but a lower success rate (35.25 %) and funding ratio (0.64). Taxidermy shows a high funding ratio (0.80) but only 4 projects and a low success rate (25 %).
